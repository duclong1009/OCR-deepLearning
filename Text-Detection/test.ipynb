# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Project_Deeplearning/project
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Project_Deeplearning/project

# %%
# !pip install Polygon3

# %%
! echo $PYTHONPATH

import os
os.environ['PYTHONPATH'] = "/content/drive/MyDrive/Project_Deeplearning/project"

! echo $PYTHONPATH
# Out:
# /env/python
# /content/drive/MyDrive/Project_Deeplearning/project

# %%
# Inference by craft
# !python inference.py --refiner_model ""
# Out:
# Loading weights from checkpoint (model/craft/2022_01_11_04_51_lr_0.0001/epoch_2_loss_150.69.pth)
# elapsed time : 82.05509185791016s

# %%
names = os.listdir("/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001")
tmp = []

for n in names:
    if ".pth" in n:
        tmp.append(os.path.join("/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001", n))

tmp = sorted(tmp, key=lambda x: int(os.path.basename(x).split("_")[0]))
for t in tmp:
    print(t)
# Out:
# /content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/1_53.666.pth
# /content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/2_51.537.pth
# /content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/3_47.076.pth
# /content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/4_48.570.pth
# /content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/5_46.196.pth
# /content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/6_46.498.pth
# /content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/7_48.316.pth
# /content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/8_47.496.pth
# /content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/9_48.529.pth
# /content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/10_47.111.pth
# /content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/11_46.313.pth
# ...

# %%
# !python eval.py --isTraingDataset 0 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/1_53.666.pth"
# !python eval.py --isTraingDataset 0 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/2_51.537.pth"
# !python eval.py --isTraingDataset 0 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/3_47.076.pth"
# !python eval.py --isTraingDataset 0 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/4_48.570.pth"
# !python eval.py --isTraingDataset 0 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/5_46.196.pth"
# !python eval.py --isTraingDataset 0 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/6_46.498.pth"
# !python eval.py --isTraingDataset 0 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/7_48.316.pth"
# !python eval.py --isTraingDataset 0 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/8_47.496.pth"
# !python eval.py --isTraingDataset 0 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/9_48.529.pth"
# !python eval.py --isTraingDataset 0 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/10_47.111.pth"
# !python eval.py --isTraingDataset 0 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/11_46.313.pth"
# !python eval.py --isTraingDataset 0 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/12_47.026.pth"
# !python eval.py --isTraingDataset 0 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/13_42.402.pth"
# !python eval.py --isTraingDataset 0 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/14_45.956.pth"
# !python eval.py --isTraingDataset 0 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/15_44.405.pth"
# !python eval.py --isTraingDataset 0 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/16_47.556.pth"
# !python eval.py --isTraingDataset 0 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/17_46.431.pth"
# !python eval.py --isTraingDataset 0 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/18_43.900.pth"
# !python eval.py --isTraingDataset 0 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/19_46.025.pth"
# !python eval.py --isTraingDataset 0 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/20_41.349.pth"

# %%
# !python eval.py --isTraingDataset 0
# Out:
# Loading weights from checkpoint (/content/drive/MyDrive/Project_Deeplearning/project/model/pretrained/craft_mlt_25k.pth)
# phase:  Test
# len:  800
# Metric:  {'micro_iou': 0.5737567541936806, 'macro_iou': 0.6327662672335138, 'precision': 0.8724027332310695, 'recall': 0.723111599144657, 'hmean': 0.7907726339074103}
# Loading weights from checkpoint (/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/1_53.666.pth)
# phase:  Test
# len:  800

# %%
# !python eval.py --isTraingDataset 1
# Out:
# Loading weights from checkpoint (/content/drive/MyDrive/Project_Deeplearning/2022_01_12_06_13_lr_0.00001/24_40.156.pth)
# phase:  Training
# len:  1200
# Metric:  {'micro_iou': 0.5610433038901537, 'macro_iou': 0.6245295267314583, 'precision': 0.8471334629989812, 'recall': 0.7095535471859121, 'hmean': 0.7722638522427441}
# Loading weights from checkpoint (/content/drive/MyDrive/Project_Deeplearning/2022_01_12_06_13_lr_0.00001/25_38.915.pth)
# phase:  Training
# len:  1200
# Metric:  {'micro_iou': 0.5668869763715562, 'macro_iou': 0.6318963164359865, 'precision': 0.8469462840323767, 'recall': 0.7143245025406307, 'hmean': 0.7750026301946343}
# Loading weights from checkpoint (/content/drive/MyDrive/Project_Deeplearning/2022_01_12_06_13_lr_0.00001/26_35.727.pth)
# phase:  Training
# len:  1200
# Metric:  {'micro_iou': 0.557965426520147, 'macro_iou': 0.6227910564122865, 'precision': 0.8432262246504306, 'recall': 0.7064116985376828, 'hmean': 0.7687794170413053}
# ...

# %%
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/1_53.666.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/2_51.537.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/3_47.076.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/4_48.570.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/5_46.196.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/6_46.498.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/7_48.316.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/8_47.496.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/9_48.529.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/10_47.111.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/11_46.313.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/12_47.026.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/13_42.402.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/14_45.956.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/15_44.405.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/16_47.556.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/17_46.431.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/18_43.900.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/19_46.025.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_01_20_lr_0.0001/20_41.349.pth"
# Out:
# Traceback (most recent call last):
#   File "eval.py", line 15, in <module>
#     from net.craft import CRAFT
#   File "/content/drive/MyDrive/Project_Deeplearning/project/net/craft.py", line 13, in <module>
#     from net.basenet.vgg16_bn import vgg16_bn
#   File "/content/drive/MyDrive/Project_Deeplearning/project/net/basenet/vgg16_bn.py", line 3, in <module>
#     from torchvision import models
#   File "/usr/local/lib/python3.7/dist-packages/torchvision/__init__.py", line 7, in <module>
#     from torchvision import datasets
#   File "/usr/local/lib/python3.7/dist-packages/torchvision/datasets/__init__.py", line 6, in <module>
#     from .mnist import MNIST, EMNIST, FashionMNIST, KMNIST, QMNIST
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 967, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 677, in _load_unlocked
# ...

# %%
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_06_13_lr_0.00001/21_37.996.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_06_13_lr_0.00001/22_38.489.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_06_13_lr_0.00001/23_37.376.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_06_13_lr_0.00001/24_40.156.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_06_13_lr_0.00001/25_38.915.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_06_13_lr_0.00001/26_35.727.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_06_13_lr_0.00001/27_38.415.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_06_13_lr_0.00001/28_37.153.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_06_13_lr_0.00001/29_36.823.pth"
# !python eval.py --isTraingDataset 1 --trained_model "/content/drive/MyDrive/Project_Deeplearning/2022_01_12_06_13_lr_0.00001/30_38.095.pth"
